# %% [markdown]
# <a href="https://colab.research.google.com/github/semihengin/Blackjack-21-Game/blob/main/Untitled_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
import graphviz
#from matplotlib import pyplot as plt
#import seaborn as sns

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Randomize the data

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=50)

# Build the Random Forest Classifier with 10 trees and the gini index criterion
clf = RandomForestClassifier(n_estimators=10, criterion='gini')

# Train the model using the training data
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
# Import the necessary libraries
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import export_graphviz

# Use the trained model to make predictions on the test data
y_pred = clf.predict(X_test)

# Create a confusion matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

# Report the accuracy, precision, recall, and f-1 score of the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='micro')
recall = recall_score(y_test, y_pred, average='micro')
f1 = f1_score(y_test, y_pred, average='micro')
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F-1 score: ", f1)
# Out:
# [[11  0  0]
#  [ 0 14  1]
#  [ 0  1 11]]
# Accuracy:  0.9473684210526315
# Precision:  0.9473684210526315
# Recall:  0.9473684210526315
# F-1 score:  0.9473684210526315

# %%
tree = clf.estimators_[7]
dot_data = export_graphviz(tree, out_file=None)
graph = graphviz.Source(dot_data)
graph#asdasd
